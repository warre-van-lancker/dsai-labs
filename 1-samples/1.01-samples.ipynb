# %% [markdown]
# # Module 1. Samples
#
# ## Learning goals
#
# - You are able to use Jupyter Notebooks (locally or in Google Colab) and configure your environment to run the code examples in this course.
# - You understand the basic terminology used in data science (indicated with 💡).
# - You are able to load a dataset in Python and explore its structure and characteristics.
#
# ## Getting Started with Jupyter Notebooks
#
# Jupyter Notebooks (or iPython Notebooks) are files with a mixture of Markdown and Python code. It's a very convenient format so we'll be using this quite a lot during this course!
#
# **Read the instructions below carefully, as they do not necessarily apply to all environments!**
#
# ### Google Colab
#
# To get started, it is not necessary to install software on your laptop. [Google Colab](https://colab.research.google.com/) is a free online iPython development environment, but it does require a Google account in order to use it. You can create a local clone of the Github repo with the lab assignments and upload the Notebook files you want to work with to Colab.
#
# Note that the Google Colab environment has older versions installed of the Python libraries that we will be using throughout this course. Usually, that's not a problem, but sometimes you will run into errors, e.g. because some parameter in our Python code didn't exist yet in that version. The solution is to add a new code block at the beginning of your Notebook file with content:

# %%
# %pip install --upgrade matplotlib
# %pip install --upgrade scipy
# %pip install --upgrade statsmodels
# Out:
# Requirement already satisfied: matplotlib in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from matplotlib) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scipy in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (1.17.1)
# Requirement already satisfied: numpy<2.7,>=1.26.4 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from scipy) (2.4.4)
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: statsmodels in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (0.14.6)
# Requirement already satisfied: numpy<3,>=1.22.3 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from statsmodels) (2.4.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from statsmodels) (1.17.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from statsmodels) (3.0.2)
# Requirement already satisfied: patsy>=0.5.6 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from statsmodels) (26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# You only have to do this in Notebooks where you encounter errors, and only for the libraries that cause these errors. The installation may take a while and you need to restart the Python runtime afterwards by clicking the button that appears.
#
# ### Local environment
#
# If you prefer to have a local development environment, you need to install Python and Visual Studio Code with the necessary extensions for working with Python (e.g. Pylance, Jupyter, Jupyter Keymap, etc.) The first time you open a Notebook file, VSCode will offer you to install these extensions.
#
# ### Windows
# To install Python and VSCode on Windows, we recommend using `winget`. First, check the latest version of Python on the [Python website](https://www.python.org/downloads/windows/). For example, at the time of writing, the latest version was 3.14.2. We'll need to specify the major and minor version (e.g. 3.14) when installing. Then, open a PowerShell or command prompt as Administrator and run:
#
# ```console
# > winget install Microsoft.VisualStudioCode
# > winget install Python.Python.3.14
# ```
#
# Remark that `winget upgrade --all` will install maintenance releases of Python, but it will not upgrade to a new major or minor version.

# %% [markdown]
# ### Linux
#
# Some Linux distributions no longer allow you to use `pip` to install Python packages globally. In that case, we recommend to work with a Python Virtual Environment. VS Code will help you to create one when you select the Python version to use for executing code cells. Alternatively, you can install and use `pipx` to install Python packages globally.

# %% [markdown]
# ### MacOS
#
# The install Python on MacOS, it's best to use [Homebrew](https://brew.sh/). After installing issue the following commands.
#
# ```console
# > brew install python
# > export PATH="/opt/homebrew/opt/python/libexec/bin:$PATH"
# ```
# You probably want to add the `export PATH` line to your `.zshrc` (or whichever shell you use)
#
# You can check everything is correctly set through
#
# ```console
# > which python
# /opt/homebrew/opt/python/libexec/bin/python
# ```
#
# It's always a good idea to set up a venv
#
# ```console
# dsai-labs> python3 -m venv .venv
# source .venv/bin/activate
# ```
#
# You should now be able to use this environment as your kernel environment in VSCode. We provided a `requirements.txt` file in the root of the repository, so you can install all necessary libraries (after activating the virtual environment) with:
#
# ```console
# > pip install -r requirements.txt
# ```

# %% [markdown]
# ## Libraries
#
# Most Python scripts (or Jupyter Notebooks) for analyzing data use the same program libraries. The most important ones are:
#
# - `numpy` - multidimensional arrays, linear algebra, etc.
# - `scipy` - mathematics, science, engineering etc.
# - `pandas` - data-analysis and -manipulation
# - `openpyxl` - reading and writing Excel files (most exercises in this course use CSV files)
# - `matplotlib`, `seaborn` - data visualisation
# - `scikit-learn` - regression and machine learning
#
# You can install these using `pip`:
#
# ```console
# > pip install matplotlib numpy openpyxl pandas scipy seaborn scikit-learn statsmodels
# ```
#
# Or, alteratively, by executing the following code block:

# %%
# %pip install matplotlib
# %pip install numpy
# %pip install openpyxl
# %pip install pandas
# %pip install scipy
# %pip install seaborn
# %pip install scikit-learn
# %pip install statsmodels
# Out:
# Requirement already satisfied: matplotlib in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from matplotlib) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (2.4.4)
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: openpyxl in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from openpyxl) (2.0.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (3.0.2)
# Requirement already satisfied: numpy>=2.3.3 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scipy in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (1.17.1)
# Requirement already satisfied: numpy<2.7,>=1.26.4 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from scipy) (2.4.4)
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from seaborn) (2.4.4)
# Requirement already satisfied: pandas>=1.2 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from seaborn) (3.0.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from seaborn) (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=8 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from scikit-learn) (2.4.4)
# Requirement already satisfied: scipy>=1.10.0 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from scikit-learn) (3.6.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: statsmodels in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (0.14.6)
# Requirement already satisfied: numpy<3,>=1.22.3 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from statsmodels) (2.4.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from statsmodels) (1.17.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from statsmodels) (3.0.2)
# Requirement already satisfied: patsy>=0.5.6 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from statsmodels) (26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/warrevl/Documents/2025-2026/Sem2/Data Science/dsai-labs/.venv/lib64/python3.14/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Since you usually need the same packages every time, it is best to put them at the top of every script or Notebook file you write. By convention, package names are often abbreviated in a consistent manner, e.g. `np` for `numpy`, `sns` for `seaborn`, etc.

# %%
# Importing the necessary packages
import numpy as np                                  # "Scientific computing"
import scipy.stats as stats                         # Statistical tests

import pandas as pd                                 # Data Frame
from pandas.api.types import CategoricalDtype

import matplotlib.pyplot as plt                     # Basic visualisation
from statsmodels.graphics.mosaicplot import mosaic  # Mosaic diagram
import seaborn as sns                               # Advanced data visualisation

# %% [markdown]
# **Tip:** you can define a code snippet in VSCode for this block of code, so you don't have to type it every time. See e.g. [this guide](https://code.visualstudio.com/docs/editor/userdefinedsnippets) on how to create code snippets in VSCode.

# %% [markdown]
# ## Basic Concepts in Data Science
#
# ### Variables and Measurement Levels
#
# In statistics and data science, a 💡**variable** is any attribute of an object of study. Variables can have 💡**values** that differ between objects. Usually, variables are classified into different types, or 💡**measurement levels**, depending on the kind of values they can take and the mathematical operations that can be performed on them. The most common types are:
#
# - 💡**Qualitative** (or categorical) variables: variables that can take on a limited number of distinct categories or labels. These are not necessarily numerical.
#
#     - 💡**Nominal** variables: categorical variables *without a specific order* or ranking among the categories (e.g., colors, types of animals).
#     - 💡**Ordinal** variables: categorical variables *with a specific order* or ranking among the categories (e.g., education level, customer satisfaction ratings).
#
# - 💡**Quantitative** (or numerical) variables: variables that can take on numerical values, which can be discrete (countable values) or continuous (any value within a range). These are usually the result of measurements. Often, there are many different values of quantitative variables in a dataset, or they may even be unique.
#
#     - 💡**Interval** variables: numerical variables where the intervals between values are meaningful, but there is no true zero point (e.g., temperature in Celsius or Fahrenheit).
#     - 💡**Ratio** variables: numerical variables with a true zero point, allowing for meaningful ratios between values (e.g., height, weight, age).
#
# It is important to correctly identify the type of variable you are working with, as this influences the choice of statistical methods and visualizations used for analysis. This is something that a computer is not very good at, so you often need to make these distinctions yourself when exploring and analyzing a dataset.
#
# ### Populations, samples, observations
#
# In data science and statistics, a 💡**population** refers to the entire set of individuals or items that you are interested in studying. A 💡**sample** is a subset of the population that is selected for analysis. A single individual or item within a population or sample is called an 💡**observation**.
#
# The goal of sampling is to gather information about the population without having to study every individual or item within it. Under certain conditions (which will be explored later in this course), you can use the information obtained from a sample to make inferences about the entire population. This is often necessary because studying the entire population can be impractical, time-consuming, or expensive.
#
# When selecting a sample from a population, it is important to ensure that the sample has specific characteristics. Specifically, a sample should be:
#
# - 💡**Randomly selected**, i.e. every individual or item in the population should have an *equal chance of being included* in the sample in order to reduce bias, but randomness alone does not guarantee that a sample is perfectly representative - especially for small sample sizes..
# - **Large enough** to provide reliable estimates of population parameters. We will explore this more in chapter 3.
# - 💡**Representative** of the population, meaning that it should accurately reflect the characteristics of the population as a whole.
#
# Ideally, a researcher would do the following to draw a sample from a population:
#
# - First and foremost, the population must be well defined
# - Then you can compile a 💡**sampling frame**, i.e. a list of all individuals in the population
# - Then, the researcher randomly selects a number of individuals from this list.
#
# It is often difficult or impossible to set up a sampling frame. In such cases, the researcher chooses a different sampling method and tries to approximate the properties listed above as closely as possible within the available time and budget.
#
# ### Sampling errors
#
#
# Even under the best of circumstances, the result within a sample is likely to deviate from the "true" value in the population, although we hope we can approach it sufficiently. So by taking a sample we inevitably introduce errors. A useful way to categorize errors is given below:
#
# - 💡**Sampling errors** are caused by the way we take a sample. We distinguish between 💡*random* or 💡*systematic* sampling errors:
#
#     - **Random sampling errors** are only due to chance and cannot be avoided. Every time you take a random sample, you will get a different result within that sample.
#
#     - **Systematic sampling errors** are worse, because they can cause the results to be biased and therefore no longer be *representative* of a population. Examples:
#
#         - Online survey: people without internet are excluded
#
#         - Street survey: only people who are currently walking there
#
#         - Voluntary survey: only interested parties participate
#
# - 💡**Non-sampling errors** are errors that occur after the sample has been taken, e.g. in the measurement and analysis. In this case, we speak of non-sampling errors and again we distinguish between *random* and *systematic*:
#
#     - **Random non-sampling errors** For example, a respondent accidentally selects or fills out a wrong answer in a survey.
#
#     - **Systematic non-sampling errors** For example:
#
#         - a measuring device that is not calibrated correctly and systematically gives a slightly higher value than the true value.
#
#         - respondents intentionally underestimate or overestimate reality (e.g. when asked about how much you smoke or drink alcohol on a daily basis)
#
# ### Representative samples
#
# A sample is said to be 💡**representative** of a population when the characteristics of the sample closely match those of the population. This means that the sample accurately reflects the diversity and distribution of key variables within the population, allowing for valid inferences to be made about the entire population based on the sample data.
#
# In a 💡**stratified** sample, the population is divided into subgroups (or strata) based on certain characteristics, and samples are drawn from each stratum in proportion to their representation in the population. This helps ensure that the sample is representative of the population as a whole, especially when certain subgroups may be underrepresented in a simple random sample.
#
# For example, if a population of 5810 individuals consists of the following age groups and genders:
#
# |           | $\le 18$ | $]18,25]$ | $]25, 40]$ | $> 40$ | Total |
# | --------: | -------: | --------: | ---------: | -----: | ----: |
# |     Woman |      500 |      1500 |       1000 |    250 |  3250 |
# |       Man |      400 |      1200 |        800 |    160 |  2560 |
# | **Total** |      900 |      2700 |       1800 |    410 |  5810 |
#
# A stratified sample of 10% would then consist of 581 individuals, with the following distribution:
#
# |           | $\le 18$ | $]18,25]$ | $]25, 40]$ | $> 40$ | Total |
# | --------: | -------: | --------: | ---------: | -----: | ----: |
# |     Woman |       50 |       150 |        100 |     25 |   325 |
# |       Man |       40 |       120 |         80 |     16 |   256 |
# | **Total** |       90 |       270 |        180 |     41 |   581 |
#
# In chapter 4, we will discuss a method that allows us to verify whether a sample is representative of a population.
#
# ### Univariate vs multivariate analysis
#
# In chapter 2, on 💡**univariate analysis**, we will focus on analyzing and summarizing data for a single variable at a time. This involves techniques such as calculating measures of central tendency (*mean*, *median*, *mode*) and measures of dispersion (*range*, *variance*, *standard deviation*), as well as creating visualizations like histograms and box plots to understand the distribution of the variable.
#
# In chapters 4 to 6, we will explore various methods to investigate whether two variables have some kind of relationship or association with each other, under the umbrella term of 💡**bivariate analysis**.
#
# The appopriate analysis or visualization technique always depends on the measurement levels of the variables involved. For example, we might use a scatter plot to visualize the relationship between two quantitative variables, or a contingency table to examine the association between two categorical variables.
#
# We say that two variables have an 💡**association** or a 💡**relationship** when the value of one variable provides some information about the value of the other variable. For example, there may be an association between age and income, where older individuals tend to have higher incomes. The variable that provides information about the other variable is called the 💡**independent variable**, while the variable being predicted or explained is called the 💡**dependent variable**.
#
# It is essential to understand that when you find an association between two variables, it does not necessarily imply a causal relationship. A phrase often used in this context is **correlation is not causation**. In other words, just because two variables are associated does not mean that one variable causes the other to change. There may be other factors at play, or the association could be entirely coincidental (*spurious correlation*). See some examples [here](https://plotlygraphs.medium.com/spurious-correlations-56752fcffb69) and [here](https://www.tylervigen.com/spurious-correlations).

# %% [markdown]
# ## Opening a Dataset, General Information
#
# Throughout this course, we will load 💡**datasets** from various sources to practice our data analysis skills. A dataset usually corresponds to a *sample* taken from a *population* being studied, and is typically organized in a tabular format where rows represent individual *observations* and columns represent different *variables*.
#
# To read a dataset into Python, you can use the `pandas` library, which provides powerful tools for data manipulation and analysis. Pandas has several functions to read data from various file formats, such as CSV (`read_csv()`), Excel (`read_excel()`), JSON (`read_json()`), and more.
#
# You can specify a path to a local file or even a URL to download the dataset directly from the web:

# %%
# Importing the Titanic dataset. (Rajagopalan, 2021, p. 106)
titanic = pd.read_csv('https://raw.githubusercontent.com/DataRepo2019/Data-files/master/titanic.csv')
# Show the first few records of the Data Frame
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# If you want to open a dataset that you stored on Google Drive (where Google Colab stores all your Notebooks), you can use the following code instead:

# %%
# # Ensure your Google Drive is accessible from within the notebook
# from google.colab import drive
# drive.mount('/content/drive')

# # Load the dataset from your Google Drive (here, we stored it in a subfolder
# # called "data")
# titanic = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/titanic.csv')
# titanic.head()

# %% [markdown]
# Let's take a look at the properties of the dataset we just loaded:

# %%
# How many  rows does the DataFrame have?
print(f"Number of rows: {len(titanic)}")
# How many columns?
print(f"Number of columns: {len(titanic.columns)}")
# How many rows and columns, i.e. the shape
print(f"The shape of the Data Frame is: {titanic.shape}")
# General information about the DataFrame
print("*"*50)
titanic.info()

# Give the data type of each column.
print("*"*50)
print(titanic.dtypes)

# How many columns of each data type are there?
#   Watch it! The book says to use get_dtype_counts(), but this method no longer exists
print("*"*50)
print(titanic.dtypes.value_counts())
# Out:
# Number of rows: 891
# Number of columns: 12
# The shape of the Data Frame is: (891, 12)
# **************************************************
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB
# **************************************************
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name               str
# Sex                str
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket             str
# Fare           float64
# Cabin              str
# Embarked           str
# dtype: object
# **************************************************
# int64      5
# str        5
# float64    2
# Name: count, dtype: int64

# %% [markdown]
# ### Indices
#
# The column "PassengerId" is not an actual variabele, but contains a number to identify each observation. You can mark this column as an index:

# %%
titanic = titanic.set_index(['PassengerId'])
titanic.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Qualitative variables
#
# Earlier, we stated that the computer is not always able to correctly identify the measurement levels of variables. In this dataset, some of the variables, such as `Survived` and `Pclass`, are incorrectly considered to be quantitative. You can correct this by explicitly converting them to a **qualitative** (categorical) variable:

# %%
# Describe the variable Survived -> is treated as quantitative
print(titanic.Survived.describe())
# Convert to a categorical variable
titanic.Survived = titanic.Survived.astype('category')
# Call desribe() again -> now it is treated as qualitative
print(titanic.Survived.describe())
# Out:
# count    891.000000
# mean       0.383838
# std        0.486592
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: Survived, dtype: float64
# count     891
# unique      2
# top         0
# freq      549
# Name: Survived, dtype: int64

# %% [markdown]
# You can also mark variables as **ordinal**, that is, with an ordering. We will do this as an example with the variable "Embarked" and order the ports by the order in which the Titanic stopped there. The Titanic departed at Southhampton, and then picked up passengers first at Cherbourg and then at Queenstown.
#
# For cases like this, define your own datatype specifying the order:

# %%
print(titanic.Embarked.unique())

embarked_type = CategoricalDtype(categories=['S', 'C', 'Q'], ordered=True)
titanic.Embarked = titanic.Embarked.astype(embarked_type)
titanic.Embarked.describe()
# Out:
# <StringArray>
# ['S', 'C', 'Q', nan]
# Length: 4, dtype: str
# count     889
# unique      3
# top         S
# freq      644
# Name: Embarked, dtype: object

# %% [markdown]
# This order will then always be respected, e.g. in graphs

# %%
sns.countplot(data=titanic, x='Embarked');

# %% [markdown]
# ### Selecting Data

# %%
# Select all observations for a single variable (i.e. a DataFrame column)
titanic.Age
# This also works (and is preferable as it will also work when the column name has a space in it):
# titanic['Age']
# This also works, but isn't very nice
# titanic.loc[:, 'Age']
# Out:
# PassengerId
# 1      22.0
# 2      38.0
# 3      26.0
# 4      35.0
# 5      35.0
#        ...
# 887    27.0
# 888    19.0
# 889     NaN
# 890    26.0
# 891    32.0
# Name: Age, Length: 891, dtype: float64

# %%
# Select adjacent columns
titanic.iloc[:, 2:4]
# Out:
#                                                           Name     Sex
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# 887                                      Montvila, Rev. Juozas    male
# 888                               Graham, Miss. Margaret Edith  female
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female
# 890                                      Behr, Mr. Karl Howell    male
# 891                                        Dooley, Mr. Patrick    male
#
# [891 rows x 2 columns]

# %% [markdown]
# You can also select multiple columns based on their names.
# This is often clearer than selecting based on position and the columns must
# not be adjacent.

# %%
titanic[['Name', 'Age', 'Cabin']] # Note: two sets of square brackets!
# Out:
#                                                           Name   Age Cabin
# PassengerId
# 1                                      Braund, Mr. Owen Harris  22.0   NaN
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0   C85
# 3                                       Heikkinen, Miss. Laina  26.0   NaN
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  C123
# 5                                     Allen, Mr. William Henry  35.0   NaN
# ...                                                        ...   ...   ...
# 887                                      Montvila, Rev. Juozas  27.0   NaN
# 888                               Graham, Miss. Margaret Edith  19.0   B42
# 889                   Johnston, Miss. Catherine Helen "Carrie"   NaN   NaN
# 890                                      Behr, Mr. Karl Howell  26.0  C148
# 891                                        Dooley, Mr. Patrick  32.0   NaN
#
# [891 rows x 3 columns]

# %%
# Observation with row number 5 (counting from zero)
print(titanic.iloc[5])

# The first 4 observations
titanic.iloc[0:4]
# Out:
# Survived                   0
# Pclass                     3
# Name        Moran, Mr. James
# Sex                     male
# Age                      NaN
# SibSp                      0
# Parch                      0
# Ticket                330877
# Fare                  8.4583
# Cabin                    NaN
# Embarked                   Q
# Name: 6, dtype: object
#             Survived  Pclass  \
# PassengerId
# 1                  0       3
# 2                  1       1
# 3                  1       3
# 4                  1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S

# %%
# Select observations where the value of Age is less than 18
titanic[titanic.Age < 18]  

# The same, but only keep the column 'Embarked'
titanic[titanic.Age < 18].Embarked

# The same, but keep columns 'Age' and 'Embarked'
titanic[titanic['Age'] < 18][['Age', 'Embarked']]
# Out:
#               Age Embarked
# PassengerId
# 8             2.0        S
# 10           14.0        C
# 11            4.0        S
# 15           14.0        S
# 17            2.0        Q
# ...           ...      ...
# 851           4.0        S
# 853           9.0        C
# 854          16.0        S
# 870           4.0        S
# 876          15.0        C
#
# [113 rows x 2 columns]

# %%
# Select all boys younger than 10
titanic.query("(Sex=='male') and (Age < 18)")
# Out:
#             Survived  Pclass                                             Name  \
# PassengerId
# 8                  0       3                   Palsson, Master. Gosta Leonard
# 17                 0       3                             Rice, Master. Eugene
# 51                 0       3                       Panula, Master. Juha Niilo
# 60                 0       3               Goodwin, Master. William Frederick
# 64                 0       3                            Skoog, Master. Harald
# 79                 1       2                    Caldwell, Master. Alden Gates
# 87                 0       3                           Ford, Mr. William Neal
# 126                1       3                     Nicola-Yarred, Master. Elias
# 139                0       3                              Osen, Mr. Olaf Elon
# 164                0       3                                  Calic, Mr. Jovo
# 165                0       3                     Panula, Master. Eino Viljami
# 166                1       3  Goldsmith, Master. Frank John William "Frankie"
# 172                0       3                             Rice, Master. Arthur
# 183                0       3            Asplund, Master. Clarence Gustaf Hugo
# 184                1       2                        Becker, Master. Richard F
# 194                1       2                       Navratil, Master. Michel M
# 221                1       3                   Sunderland, Mr. Victor Francis
# 262                1       3                Asplund, Master. Edvin Rojj Felix
# 267                0       3                        Panula, Mr. Ernesti Arvid
# 279                0       3                               Rice, Master. Eric
# 283                0       3                        de Pelsmaeker, Mr. Alfons
# 306                1       1                   Allison, Master. Hudson Trevor
# 334                0       3                  Vander Planke, Mr. Leo Edmondus
# 341                1       2                   Navratil, Master. Edmond Roger
# 349                1       3           Coutts, Master. William Loch "William"
# 353                0       3                               Elias, Mr. Tannous
# 387                0       3                  Goodwin, Master. Sidney Leonard
# 408                1       2                   Richards, Master. William Rowe
# 434                0       3                       Kallio, Mr. Nikolai Erland
# 446                1       1                        Dodge, Master. Washington
# 481                0       3                   Goodwin, Master. Harold Victor
# 490                1       3            Coutts, Master. Eden Leslie "Neville"
# 501                0       3                                 Calic, Mr. Petar
# 533                0       3                             Elias, Mr. Joseph Jr
# 550                1       2                   Davies, Master. John Morgan Jr
# 551                1       1                      Thayer, Mr. John Borland Jr
# 575                0       3                     Rush, Mr. Alfred George John
# 684                0       3                      Goodwin, Mr. Charles Edward
# 687                0       3                         Panula, Mr. Jaako Arnold
# 722                0       3                        Jensen, Mr. Svend Lauritz
# 732                0       3                         Hassan, Mr. Houssein G N
# 747                0       3                      Abbott, Mr. Rossmore Edward
# 752                1       3                              Moor, Master. Meier
# 756                1       2                        Hamalainen, Master. Viljo
# 765                0       3                           Eklund, Mr. Hans Linus
# 788                0       3                        Rice, Master. George Hugh
# 789                1       3                       Dean, Master. Bertram Vere
# 792                0       2                              Gaskell, Mr. Alfred
# 803                1       1              Carter, Master. William Thornton II
# 804                1       3                  Thomas, Master. Assad Alexander
# 820                0       3                     Skoog, Master. Karl Thorsten
# 825                0       3                     Panula, Master. Urho Abraham
# 828                1       2                            Mallet, Master. Andre
# 832                1       2                  Richards, Master. George Sibley
# 842                0       2                         Mudd, Mr. Thomas Charles
# 845                0       3                              Culumovic, Mr. Jeso
# 851                0       3          Andersson, Master. Sigvard Harald Elias
# 870                1       3                  Johnson, Master. Harold Theodor
#
#               Sex    Age  SibSp  Parch             Ticket      Fare    Cabin  \
# PassengerId
# 8            male   2.00      3      1             349909   21.0750      NaN
# 17           male   2.00      4      1             382652   29.1250      NaN
# 51           male   7.00      4      1            3101295   39.6875      NaN
# 60           male  11.00      5      2            CA 2144   46.9000      NaN
# 64           male   4.00      3      2             347088   27.9000      NaN
# 79           male   0.83      0      2             248738   29.0000      NaN
# 87           male  16.00      1      3         W./C. 6608   34.3750      NaN
# 126          male  12.00      1      0               2651   11.2417      NaN
# 139          male  16.00      0      0               7534    9.2167      NaN
# 164          male  17.00      0      0             315093    8.6625      NaN
# 165          male   1.00      4      1            3101295   39.6875      NaN
# 166          male   9.00      0      2             363291   20.5250      NaN
# 172          male   4.00      4      1             382652   29.1250      NaN
# 183          male   9.00      4      2             347077   31.3875      NaN
# 184          male   1.00      2      1             230136   39.0000       F4
# 194          male   3.00      1      1             230080   26.0000       F2
# 221          male  16.00      0      0    SOTON/OQ 392089    8.0500      NaN
# 262          male   3.00      4      2             347077   31.3875      NaN
# 267          male  16.00      4      1            3101295   39.6875      NaN
# 279          male   7.00      4      1             382652   29.1250      NaN
# 283          male  16.00      0      0             345778    9.5000      NaN
# 306          male   0.92      1      2             113781  151.5500  C22 C26
# 334          male  16.00      2      0             345764   18.0000      NaN
# 341          male   2.00      1      1             230080   26.0000       F2
# 349          male   3.00      1      1         C.A. 37671   15.9000      NaN
# 353          male  15.00      1      1               2695    7.2292      NaN
# 387          male   1.00      5      2            CA 2144   46.9000      NaN
# 408          male   3.00      1      1              29106   18.7500      NaN
# 434          male  17.00      0      0  STON/O 2. 3101274    7.1250      NaN
# 446          male   4.00      0      2              33638   81.8583      A34
# 481          male   9.00      5      2            CA 2144   46.9000      NaN
# 490          male   9.00      1      1         C.A. 37671   15.9000      NaN
# 501          male  17.00      0      0             315086    8.6625      NaN
# 533          male  17.00      1      1               2690    7.2292      NaN
# 550          male   8.00      1      1         C.A. 33112   36.7500      NaN
# 551          male  17.00      0      2              17421  110.8833      C70
# 575          male  16.00      0      0         A/4. 20589    8.0500      NaN
# 684          male  14.00      5      2            CA 2144   46.9000      NaN
# 687          male  14.00      4      1            3101295   39.6875      NaN
# 722          male  17.00      1      0             350048    7.0542      NaN
# 732          male  11.00      0      0               2699   18.7875      NaN
# 747          male  16.00      1      1          C.A. 2673   20.2500      NaN
# 752          male   6.00      0      1             392096   12.4750     E121
# 756          male   0.67      1      1             250649   14.5000      NaN
# 765          male  16.00      0      0             347074    7.7750      NaN
# 788          male   8.00      4      1             382652   29.1250      NaN
# 789          male   1.00      1      2          C.A. 2315   20.5750      NaN
# 792          male  16.00      0      0             239865   26.0000      NaN
# 803          male  11.00      1      2             113760  120.0000  B96 B98
# 804          male   0.42      0      1               2625    8.5167      NaN
# 820          male  10.00      3      2             347088   27.9000      NaN
# 825          male   2.00      4      1            3101295   39.6875      NaN
# 828          male   1.00      0      2    S.C./PARIS 2079   37.0042      NaN
# 832          male   0.83      1      1              29106   18.7500      NaN
# 842          male  16.00      0      0        S.O./P.P. 3   10.5000      NaN
# 845          male  17.00      0      0             315090    8.6625      NaN
# 851          male   4.00      4      2             347082   31.2750      NaN
# 870          male   4.00      1      1             347742   11.1333      NaN
#
#             Embarked
# PassengerId
# 8                  S
# 17                 Q
# 51                 S
# 60                 S
# 64                 S
# 79                 S
# 87                 S
# 126                C
# 139                S
# 164                S
# 165                S
# 166                S
# 172                Q
# 183                S
# 184                S
# 194                S
# 221                S
# 262                S
# 267                S
# 279                Q
# 283                S
# 306                S
# 334                S
# 341                S
# 349                S
# 353                C
# 387                S
# 408                S
# 434                S
# 446                S
# 481                S
# 490                S
# 501                S
# 533                C
# 550                S
# 551                C
# 575                S
# 684                S
# 687                S
# 722                S
# 732                C
# 747                S
# 752                S
# 756                S
# 765                S
# 788                Q
# 789                S
# 792                S
# 803                S
# 804                C
# 820                S
# 825                S
# 828                C
# 832                S
# 842                S
# 845                S
# 851                S
# 870                S

# %% [markdown]
# ### Dropping Data and Working with Missing Data
#
# Pandas tries to make working with missing data as easy as possible. E.g., all of the descriptive statistics on pandas objects exclude missing data by default.

# %% [markdown]
# Let's start by reading the titanic data again.

# %%
titanic = pd.read_csv('https://raw.githubusercontent.com/DataRepo2019/Data-files/master/titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# The `PassengerId` column is identical to the index hence it doesn't provide any additional useful information. Let's drop this column (rather than setting it as the index as before). This can be done using `drop`.

# %%
titanic.drop("PassengerId", axis="columns")
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    female  35.0      1      0            113803  53.1000  C123        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %% [markdown]
# Notice that we didn't actually change the `titanic` `DataFrame`.  We can either assign the result of `drop` to a (new) `DataFrame`
# or we can use `inplace=True`.

# %%
titanic.head(3) # PassengerId is still here
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
titanic = titanic.drop("PassengerId", axis="columns")
titanic.head(3) # PassengerId is now gone
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# From the output of the `info` method we can infer that certain columns contain many missing values, e.g. `Cabin` only contains 204 non-missing values.
# For the purposes of illustration, let's drop any row that has a missing observation by using
# the default behaviour of the `dropna` method.

# %%
titanic.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    str
#  3   Sex       891 non-null    str
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    str
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    str
#  10  Embarked  889 non-null    str
# dtypes: float64(2), int64(4), str(5)
# memory usage: 76.7 KB

# %%
cleaned = titanic.dropna() # Drop any row that has at least one missing value
print(cleaned.info())
cleaned.head(5)
# Out:
# <class 'pandas.DataFrame'>
# Index: 183 entries, 1 to 889
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  183 non-null    int64
#  1   Pclass    183 non-null    int64
#  2   Name      183 non-null    str
#  3   Sex       183 non-null    str
#  4   Age       183 non-null    float64
#  5   SibSp     183 non-null    int64
#  6   Parch     183 non-null    int64
#  7   Ticket    183 non-null    str
#  8   Fare      183 non-null    float64
#  9   Cabin     183 non-null    str
#  10  Embarked  183 non-null    str
# dtypes: float64(2), int64(4), str(5)
# memory usage: 17.2 KB
# None
#     Survived  Pclass                                               Name  \
# 1          1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3          1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 6          0       1                            McCarthy, Mr. Timothy J
# 10         1       3                    Sandstrom, Miss. Marguerite Rut
# 11         1       1                           Bonnell, Miss. Elizabeth
#
#        Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 1   female  38.0      1      0  PC 17599  71.2833   C85        C
# 3   female  35.0      1      0    113803  53.1000  C123        S
# 6     male  54.0      0      0     17463  51.8625   E46        S
# 10  female   4.0      1      1   PP 9549  16.7000    G6        S
# 11  female  58.0      0      0    113783  26.5500  C103        S

# %% [markdown]
# This would only keep 183 values, which isn't a lot. We could also choose to drop only the rows that consist of nothing but missing values (there are no such rows in the `titanic` `DataFrame`), but here you can see how this would be done.

# %%
cleaned = titanic.dropna(how="all")
cleaned.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    str
#  3   Sex       891 non-null    str
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    str
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    str
#  10  Embarked  889 non-null    str
# dtypes: float64(2), int64(4), str(5)
# memory usage: 76.7 KB

# %% [markdown]
# Instead of relying on `info` to compute the number of non-missing values we can also use the `isnull` and/or `notnull` methods.
# `notnull` computes a boolean `DataFrame` where an entry is `True` if and only if that entry is considered to be non-missing in the original `DataFrame`. We can then use `sum` to compute the sum of each column. This gives the number of non-missing values per column.

# %%
not_null_df = titanic.notnull()
print(not_null_df.tail(3))
print("Number of non null values in each column:")
print(not_null_df.sum())
# Out:
#      Survived  Pclass  Name   Sex    Age  SibSp  Parch  Ticket  Fare  Cabin  \
# 888      True    True  True  True  False   True   True    True  True  False
# 889      True    True  True  True   True   True   True    True  True   True
# 890      True    True  True  True   True   True   True    True  True  False
#
#      Embarked
# 888      True
# 889      True
# 890      True
# Number of non null values in each column:
# Survived    891
# Pclass      891
# Name        891
# Sex         891
# Age         714
# SibSp       891
# Parch       891
# Ticket      891
# Fare        891
# Cabin       204
# Embarked    889
# dtype: int64

# %% [markdown]
# An even easier alternative is to simply use `count` on the `DataFrame`.

# %%
print(titanic.count())
# Out:
# Survived    891
# Pclass      891
# Name        891
# Sex         891
# Age         714
# SibSp       891
# Parch       891
# Ticket      891
# Fare        891
# Cabin       204
# Embarked    889
# dtype: int64

# %% [markdown]
# The `Cabin` column has too many missing values, so probably isn't useful. For the `Age` column, we can *impute* the missing values, e.g. with the average age of all passengers. (We will see later what this means exactly). Let's do this using `fillna`.

# %%
# First compute the average age
avg_age = titanic['Age'].mean()
print(f"(Rounded) Average age of passengers: {round(avg_age)}")
titanic = titanic.fillna(value={'Age' : avg_age})
print("We should now confirm that the 'Age' column no longer has missing values")
titanic.info()
# Out:
# (Rounded) Average age of passengers: 30
# We should now confirm that the 'Age' column no longer has missing values
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    str
#  3   Sex       891 non-null    str
#  4   Age       891 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    str
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    str
#  10  Embarked  889 non-null    str
# dtypes: float64(2), int64(4), str(5)
# memory usage: 76.7 KB

# %% [markdown]
# ### Creating New Columns

# %% [markdown]
# We use a dataset containing $NO_2$ measurements (expressed as ppb - parts pro billion) at the stations of Paris, Antwerp and London.
#
# Let's read the data and check whether it worked.

# %%
URL = "https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/air_quality_no2.csv"
air_quality = pd.read_csv(URL)
print(air_quality.info())
air_quality.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   datetime         1035 non-null   str
#  1   station_antwerp  95 non-null     float64
#  2   station_paris    1004 non-null   float64
#  3   station_london   969 non-null    float64
# dtypes: float64(3), str(1)
# memory usage: 32.5 KB
# None
#               datetime  station_antwerp  station_paris  station_london
# 0  2019-05-07 02:00:00              NaN            NaN            23.0
# 1  2019-05-07 03:00:00             50.5           25.0            19.0
# 2  2019-05-07 04:00:00             45.0           27.7            19.0
# 3  2019-05-07 05:00:00              NaN           50.4            16.0
# 4  2019-05-07 06:00:00              NaN           61.9             NaN

# %% [markdown]
# We see that
# - the dates are stored as strings (str dtype)
# - `datetime` is added as a column and we have a `RangeIndex`.
#
# We would like to
# - parse the dates, so that they are available as `datetime` objects
# - index the `DataFrame` rows by this date.
#
# This can be achieved by specifying the index column and by indicating that dates must be parsed on `read_csv`. Let's try again.

# %%
air_quality = pd.read_csv(URL, index_col=0, parse_dates=True)
print(air_quality.info())
air_quality.head()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 1035 entries, 2019-05-07 02:00:00 to 2019-06-21 02:00:00
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   station_antwerp  95 non-null     float64
#  1   station_paris    1004 non-null   float64
#  2   station_london   969 non-null    float64
# dtypes: float64(3)
# memory usage: 32.3 KB
# None
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN

# %% [markdown]
# We can clearly see the difference!
#
# Working with the datetime datatype is especially interesting if you want to do date time calculations:

# %%
# calculate difference between each index and the previous one, expressed in hours
# to_series() converts the index data type to a pandas Series
# diff() calculates the difference between each value and the previous one
# dt.total_seconds() converts the difference to seconds, and we divide by 3600 to convert to hours
air_quality['timespan'] = air_quality.index.to_series().diff().dt.total_seconds() / 3600
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london  timespan
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0       NaN
# 2019-05-07 03:00:00             50.5           25.0            19.0       1.0
# 2019-05-07 04:00:00             45.0           27.7            19.0       1.0
# 2019-05-07 05:00:00              NaN           50.4            16.0       1.0
# 2019-05-07 06:00:00              NaN           61.9             NaN       1.0

# %%
# now we can check if the timespan is consistent (i.e. always 1 hour)
air_quality.timespan.value_counts()
# Out:
# timespan
# 1.0     1031
# 11.0       2
# 27.0       1
# Name: count, dtype: int64

# %% [markdown]
# There are clearly some gaps.

# %% [markdown]
# ### Creating a New Column Derived from (an) Existing Column(s)

# %% [markdown]
# Assume we would like to express the concentration of the station in London in $\mu g/m^3$
# *(If we assume temperature of 25 degrees Celsius and pressure of 1013 hPa, the conversion factor is 1.882)*

# %%
air_quality["london_mg_per_cubic"] = air_quality["station_london"] * 1.882
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london  timespan  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0       NaN
# 2019-05-07 03:00:00             50.5           25.0            19.0       1.0
# 2019-05-07 04:00:00             45.0           27.7            19.0       1.0
# 2019-05-07 05:00:00              NaN           50.4            16.0       1.0
# 2019-05-07 06:00:00              NaN           61.9             NaN       1.0
#
#                      london_mg_per_cubic
# datetime
# 2019-05-07 02:00:00               43.286
# 2019-05-07 03:00:00               35.758
# 2019-05-07 04:00:00               35.758
# 2019-05-07 05:00:00               30.112
# 2019-05-07 06:00:00                  NaN

# %% [markdown]
# To create a new column, use the `[]` brackets with the new column name at the left side of the assignment.  The computation is done **element wise**, hence there is no need for an explicit loop!
#
# We can also use multiple columns to derive a new column.
#
# Let's check the ratio of the values in Paris versus Antwerp and save the result in a new column.

# %%
air_quality["ratio_paris_antwerp"] = air_quality["station_paris"] / air_quality["station_antwerp"]
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london  timespan  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0       NaN
# 2019-05-07 03:00:00             50.5           25.0            19.0       1.0
# 2019-05-07 04:00:00             45.0           27.7            19.0       1.0
# 2019-05-07 05:00:00              NaN           50.4            16.0       1.0
# 2019-05-07 06:00:00              NaN           61.9             NaN       1.0
#
#                      london_mg_per_cubic  ratio_paris_antwerp
# datetime
# 2019-05-07 02:00:00               43.286                  NaN
# 2019-05-07 03:00:00               35.758             0.495050
# 2019-05-07 04:00:00               35.758             0.615556
# 2019-05-07 05:00:00               30.112                  NaN
# 2019-05-07 06:00:00                  NaN                  NaN

# %% [markdown]
# We can also perform more general mappings on columns, either using a function or a dictionary.
#
# Let's work with the Titanic data once more.  Let's say we want to numerically encode the `Sex` column, this can be done as follows. First let's check the unique values in the `Sex` column.

# %%
titanic['Sex'].unique()
# Out:
# <StringArray>
# ['male', 'female']
# Length: 2, dtype: str

# %%
mapping_dict = {'male' : 0, 'female' : 1}
titanic['Sex'] = titanic['Sex'].map(mapping_dict)

# %% [markdown]
# Let's check whether it worked.

# %%
titanic.head()
# Out:
#    Survived  Pclass                                               Name  Sex  \
# 0         0       3                            Braund, Mr. Owen Harris    0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1
# 2         1       3                             Heikkinen, Miss. Laina    1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1
# 4         0       3                           Allen, Mr. William Henry    0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  38.0      1      0          PC 17599  71.2833   C85        C
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  35.0      1      0            113803  53.1000  C123        S
# 4  35.0      0      0            373450   8.0500   NaN        S

# %% [markdown]
# Let's add a new feature (i.e. a new column). When `Age` is less than 12 we will call this passenger a `child`,
# between 12 and 18 a `teen` and over 18 will be `adult`s.  First, we define a Python function implementing
# this mapping, and then we apply it to the `Age` column.

# %%
def age_to_category(age):
    if age < 12:
        return "child"
    if age < 18:
        return "teen"
    return "adult"

titanic['AgeCategory'] = titanic['Age'].map(age_to_category)
titanic.head()
# Out:
#    Survived  Pclass                                               Name  Sex  \
# 0         0       3                            Braund, Mr. Owen Harris    0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1
# 2         1       3                             Heikkinen, Miss. Laina    1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1
# 4         0       3                           Allen, Mr. William Henry    0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked AgeCategory
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S       adult
# 1  38.0      1      0          PC 17599  71.2833   C85        C       adult
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S       adult
# 3  35.0      1      0            113803  53.1000  C123        S       adult
# 4  35.0      0      0            373450   8.0500   NaN        S       adult

# %% [markdown]
# Here, we only scratched the surface of what is possible with pandas (and indeed, whole books have been written about pandas). In general the pandas getting started guide, the user guide and the API reference are very good resources to find additional information. You can find
# all of these [here](https://pandas.pydata.org/pandas-docs/stable/index.html).
